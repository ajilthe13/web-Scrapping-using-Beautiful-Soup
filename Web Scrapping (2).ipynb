# %% [markdown]
# ### Importing Required Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### Store Website in Variable

# %%
website = "https://www.reliancedigital.in/smart-phones/c/S101711?searchQuery=Samsung"

# %% [markdown]
# ### Get Request

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# The HTTP Request was successfull

# %% [markdown]
# ### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0" name="viewport"/>
# <meta content="#e42529" name="theme-color"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#e42529" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="A2HS Test" name="apple-mobile-web-app-title"/>
# <link href="/build/client/images/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link content="#e42529" href="/build/client/images/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/manifest.json" rel="manifest"/>
# <link crossorigin="" href="https://www.reliancedigital.in" rel="preconnect"/>
# <link crossorigin="" href="//fonts.gstatic.com" rel="preconnect"/>
# <link crossorigin="" href="https://www.googletagmanager.com" rel="preconnect">
# <link crossorigin="" href="http://b.scorecardresearch.com" rel="preconnect">
# <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect">
# <link crossorigin="" href="https://www.google.com" rel="preconnect">
# <link crossorigin="" href="https://stats.g.doubleclick.net" rel="preconnect">
# <link crossorigin="" href="https://www.google.co.in" rel="preconnect">
# <link href="//connect.facebook.net" rel="dns-prefetch"/>
# <link as="script" href="/build/client/js/vendor1e0369bd6.js" rel="preload"/>
# <link as="script" href="/build/client/js/vendor295434489.js" rel="preload"/>
# <link as="script" href="/build/client/js/clientWebfbdf9339.js" rel="preload"/>
# <link as="script" href="/build/client/js/AutoSuggestf52acbb4.js" rel="preload"/><link as="script" href="/build/client/js/ProductLandingPageWd5779d6e.js" rel="preload"/>
# <link as="style" href="/build/client/css/AutoSuggestf77429cc.css" rel="preload"/><link as="style" href="/build/client/css/ProductLandingPageWd2e0e942.css" rel="preload"/>
# <style id="clientWeb">.blur-outofstock{-webkit-filter:blur(8px);filter:blur(8px)}.autoAdjust{top:0;bottom:0;left:0;right:0;position:absolute}.imgCenter{position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);margin:auto}.slick-slider{position:relative;-webkit-box-sizing:border-box;box-sizing:border-box;-webkit-touch-callout:none;-khtml-user-select:none;-ms-touch-action:pan-y;touch-action:pan-y;-webkit-tap-highlight-color:transparent}.slick-slide:focus div{outline:none!important}.slick-list{position:relative;display:block;overflow:hidden;margin:0;padding:0}.slick-list:focus{outline:none}.slick-list.dragging{cursor:pointer;cursor:hand}.slick-slider .slick-list,.slick-slider .slick-track{-webkit-transform:translateZ(0);-ms-transform:translateZ(0);transform:translateZ(0)}.slick-track{position:relative;top:0;left:0;display:-webkit-box;display:-ms-flexbox;display:flex;margin-left:auto;margin-right:auto}.slick-track:after,.slick-track:before{display:table;content:""}.slick-track:after{clear:both}.slick-loading .slick-track{visibility:hidden}.slick-slide{display:none;float:left;height:100%;min-height:1px}[dir=rtl] .slick-slide{float:right}.slick-slide img{display:block;margin:auto}.slick-slide.slick-loading img{display:none}.slick-slide.dragging img{pointer-events:none}.slick-initialized .slick-slide{display:block}.slick-loading .slick-slide{visibility:hidden}.slick-vertical .slick-slide{display:block;height:auto;border:1px solid rgba(0,0,0,0)}.slick-arrow.slick-hidden{display:none}.multi-slider.slick-slider{display:-webkit-box;display:-ms-flexbox;display:flex}.multi-slider .slick-next,.multi-slider .slick-prev{font-size:0;background:none;z-index:1;cursor:pointer;border:none;height:100%;margin:auto}.multi-slider .slick-prev{margin-left:8px}.multi-slider .slick-next{margin-right:8px}.multi-slider .slick-prev:after{content:"\f104";font:40px/1 FontAwesome}.multi-slider .slick-next:after{content:"\f105";font:40px/1 FontAwesome}.multi-slider .slick-next:hover:after,.multi-slider .slick-prev:hover:after{color:#7e7e7e}.single-slider .slick-next,.single-slider .slick-prev{font-size:0;position:absolute;bottom:50%;border:0;background:none;z-index:1;cursor:pointer}.single-slider .slick-prev:after{content:"\f104";font:40px/1 FontAwesome}.single-slider .slick-next{right:0}.single-slider .slick-next:after{content:"\f105";font:40px/1 FontAwesome}.single-slider .slick-next:hover:after,.single-slider .slick-prev:hover:after{color:#7e7e7e}.slider{display:block;max-width:100%;overflow:hidden;-ms-scroll-snap-type:x mandatory;scroll-snap-type:x mandatory}.slider__auto{overflow:auto;white-space:nowrap;scroll-behavior:smooth;display:-webkit-box;display:-ms-flexbox;display:flex}.slider__auto::-webkit-scrollbar{display:none}.slider__inner{will-change:auto;-webkit-transform:translateZ(0);transform:translateZ(0);-webkit-transition:-webkit-transform .25s cubic-bezier(0,0,.3,1) 0s;transition:-webkit-transform .25s cubic-bezier(0,0,.3,1) 0s;-o-transition:transform .25s cubic-bezier(0,0,.3,1) 0s;transition:transform .25s cubic-bezier(0,0,.3,1) 0s;transition:transform .25s cubic-bezier(0,0,.3,1) 0s,-webkit-transform .25s cubic-bezier(0,0,.3,1) 0s;display:-webkit-box;display:-ms-flexbox;display:flex;-ms-touch-action:manipulation;touch-action:manipulation}.slider::-webkit-scrollbar{display:none}.slider__item{scroll-snap-align:start;display:inline-block;vertical-align:top;white-space:normal;padding:4px;overflow:hidden;display:-webkit-box;display:-ms-flexbox;display:flex;-ms-flex-negative:0;flex-shrink:0}.slider__item a{color:inherit}.slider__vertical{display:block}.slider__vertical .slider__item{width:100%!important}.slider__outer{position:relative}.slider-dots{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;padding:0 15%}@-webkit-keyframes mymove{0%{width:0;background:#999}to{width:100%;background:#999}}@keyframes ...
# <link href="/build/client/css/AutoSuggestf77429cc.css" rel="stylesheet">
# <link href="/build/client/css/ProductLandingPageWd2e0e942.css" rel="stylesheet">
# <link as="font" crossorigin="" href="/build/client/fonts/fontawesome-webfont.woff2" rel="preload"/>
# <link href="https://www.reliancedigital.in/smart-phones/c/S101711" rel="canonical">
# <style data-styled="ieKcal cQnxgK jzNZAg fqxzzJ iEWIKP lcvyjZ iEkImn jWpSeo gzmYXA glOPZP kgiZNr hMTXuH iCsDm hJDoTy dmrFHq bcMriR hIQkJC gzZuNI jaGTjb hILMWQ dmBTBc dwlVOi gCqLPo bJdXEw hXuWdI iPzCkS hyGPxs jBpWJl dUjbjz gtYkTT dcQfMc fAvZGN fhVLwy rZMiY eEhwuX gfrwYo jxSiES dRXnYU fPGbEv jCFaIo hnacHk vGZum cGJDvA eYJTTK" data-styled-version="4.3.2">
# /* sc-component-id: sc-bwzfXH */
# .jzNZAg.jzNZAg.jzNZAg{width:14px;height:100%;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.fqxzzJ.fqxzzJ.fqxzzJ{margin:auto;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.iEWIKP.iEWIKP.iEWIKP{width:35%;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.lcvyjZ.lcvyjZ.lcvyjZ{margin:0px 0px 16px 0px;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.iEkImn.iEkImn.iEkImn{padding:4px;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.jWpSeo.jWpSeo.jWpSeo{margin:8px 0px 0px;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.gzmYXA.gzmYXA.gzmYXA{margin:12px 4px 8px 0px;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.glOPZP.glOPZP.glOPZP{bottom:0px;left:0px;width:100%;height:40px;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.kgiZNr.kgiZNr.kgiZNr{width:50%;height:40px;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.hMTXuH.hMTXuH.hMTXuH{margin-left:8px;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}
# /* sc-component-id: sc-htpNat */
# .ieKcal.ieKcal.ieKcal{position:fixed;z-index:111;}.cQnxgK.cQnxgK.cQnxgK{position:absolute;top:8px;right:16px;z-index:111;}
# /* sc-component-id: sc-bxivhb */
# @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.dmrFHq{color:#ffffff;background-color:#e42529;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;} @media (max-width:767px){.dmrFHq{background-color:#f0f8ff;}} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.bcMriR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.hIQkJC{font-size:18px;font-weight:500;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.gzZuNI{display:inline-block;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.jaGTjb{font-size:13px;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.hILMWQ{overflow:hidden;white-space:nowrap;text-overflow:ellipsis;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.dmBTBc{color:#1f4985;font-size:15px;font-weight:600;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.dwlVOi{color:#43a047;font-size:12px;font-weight:600;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}
# /* sc-component-id: sc-ifAKCX */
# .bJdXEw{background-color:#ffffff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;} @media (max-width:768px){}
# /* sc-component-id: sc-jzJRlG */
# .dUjbjz{text-align:center;-webkit-text-decoration:none;text-decoration:none;display:inline-block;padding:0 12px;outline:none;border:none;cursor:pointer;font-family:inherit;line-height:40px;text-transform:uppercase;font-weight:600;font-size:16px;border-radius:3px;float:none;} .dUjbjz:disabled{cursor:not-allowed;opacity:0.65;} .dUjbjz.disabled,.dUjbjz[disabled]{cursor:not-allowed;-webkit-filter:alpha(opacity=65);filter:alpha(opacity=65);box-shadow:none;opacity:0.65;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){} @media (max-width:767px){}.gtYkTT{text-align:center;-webkit-text-decoration:none;text-decoration:none;display:inline-block;padding:0 12px;outline:none;border:none;cursor:pointer;font-family:inherit;line-height:34px;text-transform:uppercase;font-weight:400;font-size:14px;border-radius:3px;float:none;color:#e42529;border:0;border-radius:0;background:transparent;padding:0;font-weight:400;line-height:34px;text-transform:none;text-align:center;-webkit-text-decoration:none;text-decoration:none;color:#1f4985;} .gtYkTT:disabled{cursor:not-allowed;opacity:0.65;} .gtYkTT.disabled,.gtYkTT[disabled]{cursor:not-allowed;-webkit-filter:alpha(opacity=65);filter:alpha(opacity=65);box-shadow:none;opacity:0.65;} .gtYkTT:hover{color:#d9534f;} .gtYkTT:hover{color:#1774ef;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){} @media (max-width:767px){.gtYkTT{font-size:13px;border-radius:0;}}
# /* sc-component-id: sc-chPdSV */
# .dRXnYU{cursor:pointer;}
# /* sc-component-id: sc-hMqMXs */
# .hXuWdI{width:100%;}
# /* sc-component-id: sc-kEYyzF */
# .jBpWJl{background-color:transparent;top:11px;box-sizing:border-box;color:#80868b;font-size:13px;font-family:roboto,arial,sans-serif;font-weight:400;line-height:16px;left:10px;max-width:calc(100% - (2 * 8px));overflow:hidden;padding:0 8px;text-overflow:ellipsis;-webkit-transition:-webkit-transform 150ms cubic-bezier(0.4,0,0.2,1),opacity 150ms cubic-bezier(0.4,0,0.2,1);-webkit-transition:transform 150ms cubic-bezier(0.4,0,0.2,1),opacity 150ms cubic-bezier(0.4,0,0.2,1);transition:transform 150ms cubic-bezier(0.4,0,0.2,1),opacity 150ms cubic-bezier(0.4,0,0.2,1);white-space:nowrap;width:auto;z-index:1;pointer-events:none;position:absolute;} @media (min-width:768px) and (max-width:991px){.jBpWJl{font-size:13px;}} @media (max-width:767px){.jBpWJl{font-size:13px;}}
# /* sc-component-id: sc-kkGfuU */
# .hyGPxs{width:100%;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-flex-shrink:1;-ms-flex-negative:1;flex-shrink:1;border:1px solid #dadce0;background-color:transparent;display:block;font-family:'Open Sans',sans-serif;line-height:26px;outline:none;border-radius:3px;color:#202124;font-size:14px;height:36px;padding:8px 16px;z-index:1;} @media (max-width:767px){.hyGPxs{font-size:13px;}} .hyGPxs:disabled{color:#333333 !important;border:1px solid #bcbcbc;opacity:0.8;cursor:not-allowed;} .hyGPxs:-moz-read-only{color:#bbbbbb;cursor:not-allowed;} .hyGPxs:read-only{color:#bbbbbb;cursor:not-allowed;} .hyGPxs:-webkit-autofill,.hyGPxs:-webkit-autofill:focus,.hyGPxs:-webkit-autofill:hover{background-color:transparent;font-size:14px;-webkit-transition:background-color 5000s ease-in-out 0s;transition:background-color 5000s ease-in-out 0s;} @media (max-width:767px){.hyGPxs:-webkit-autofill,.hyGPxs:-webkit-autofill:focus,.hyGPxs:-webkit-autofill:hover{font-size:13px;}} .hyGPxs:not([disabled]):focus{border:1px solid #1774ef;} .hyGPxs:not([disabled]):focus ~ .sc-kEYyzF{-webkit-transform:translateY(-140%);-ms-transform:translateY(-140%);transform:translateY(-140%);font-size:12px;line-height:12px;color:#1774ef;background-color:#ffffff;} @media (max-width:767px){.hyGPxs:not([disabled]):focus ~ .sc-kEYyzF{background-color:#ffffff;}} .hyGPxs:-webkit-autofill ~ .sc-kEYyzF{-webkit-transform:translateY(-140%);-ms-transform:translateY(-140%);transform:translateY(-140%);font-size:12px;line-height:12px;color:#1774ef;background-color:#ffffff;} @media (max-width:767px){.hyGPxs:-webkit-autofill ~ .sc-kEYyzF{background-color:#ffffff;}} .hyGPxs:disabled ~ .sc-kEYyzF{background-color:transparent;color:#bbbbbb;}
# /* sc-component-id: sc-iAyFgw */
# .iPzCkS{position:relative;margin-top:4px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-flex-shrink:1;-ms-flex-negative:1;flex-shrink:1;} .iPzCkS .sc-kEYyzF{-webkit-transform:translateY(-140%);-ms-transform:translateY(-140%);transform:translateY(-140%);font-size:12px;line-height:12px;color:#1774ef;background-color:#ffffff;} @media (max-width:767px){.iPzCkS .sc-kEYyzF{background-color:#ffffff;}} .iPzCkS .sc-kkGfuU{border:1px solid #1774ef;} .iPzCkS .sc-kkGfuU:disabled{border:1px solid #dadce0;} .iPzCkS .sc-kkGfuU:disabled ~ .sc-kEYyzF{background-color:#ffffff;color:#80868b;} @media (max-width:767px){.iPzCkS .sc-kkGfuU:disabled ~ .sc-kEYyzF{background-color:#ffffff;}} .iPzCkS.errorBox .sc-kkGfuU{border:1px solid #d32f2f;} .iPzCkS.errorBox .sc-kkGfuU:disabled ~ .sc-kEYyzF{-webkit-transform:translateY(-140%);-ms-transform:translateY(-140%);transform:translateY(-140%);font-size:12px;line-height:12px;color:#d32f2f;background-color:#ffffff;} @media (max-width:767px){.iPzCkS.errorBox .sc-kkGfuU:disabled ~ .sc-kEYyzF{background-color:#ffffff;}} .iPzCkS.errorBox .sc-kkGfuU:not([disabled]):focus ~ .sc-kEYyzF{-webkit-transform:translateY(-140%);-ms-transform:translateY(-140%);transform:translateY(-140%);font-size:12px;line-height:12px;background-color:#ffffff;color:#d32f2f;} @media (max-width:767px){.iPzCkS.errorBox .sc-kkGfuU:not([disabled]):focus ~ .sc-kEYyzF{background-color:#ffffff;}} .iPzCkS.errorBox .sc-kEYyzF{-webkit-transform:translateY(-140%);-ms-transform:translateY(-140%);transform:translateY(-140%);font-size:12px;line-height:12px;background-color:#ffffff;color:#d32f2f;} @media (max-width:767px){.iPzCkS.errorBox .sc-kEYyzF{background-color:#ffffff;}}
# /* sc-component-id: sc-csuQGl */
# .gCqLPo{cursor:pointer;} .gCqLPo.gCqLPo.gCqLPo{padding:12px 0px;width:auto;height:42px;} @media (max-width:767px){.gCqLPo.gCqLPo.gCqLPo{padding:12px;width:100%;max-width:100%;}} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}
# /* sc-component-id: sc-Rmtcm */
# .fPGbEv{margin-left:-16px;margin-right:-16px;} .fPGbEv::after,.fPGbEv::before{content:" ";display:table;} .fPGbEv::after{clear:both;} @media (min-width:768px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){}.jCFaIo{position:relative;min-height:1px;padding-left:16px;padding-right:16px;float:left;width:100%;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){} @media (min-width:768px){.jCFaIo{float:left;width:100%;}} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){.jCFaIo{float:left;width:100%;}}
# /* sc-component-id: sc-bRBYWo */
# .iCsDm.iCsDm.iCsDm{width:auto;}
# /* sc-component-id: sc-frDJqD */
# .dcQfMc{width:auto;padding:0;padding-left:0;margin:0;margin-bottom:0;display:inline-block;}
# /* sc-component-id: sc-kvZOFW */
# .fAvZGN{margin:0;font-size:14px;width:auto;padding-left:30px;position:relative;cursor:pointer;font-weight:400;line-height:16px;display:inline-block;outline:none;} @media (max-width:767px){.fAvZGN{font-size:13px;}}
# /* sc-component-id: sc-hqyNC */
# .rZMiY{font-size:14px;line-height:18px;font-weight:400;font-family:'Open Sans',sans-serif;outline:none;} @media (min-width:768px) and (max-width:991px){.rZMiY{font-size:13px;}} @media (max-width:767px){.rZMiY{font-size:13px;}}
# /* sc-component-id: sc-jbKcbu */
# .eEhwuX{background:#ffffff;position:absolute;top:0;left:2px;width:18px;height:18px;outline:none;border:1px solid #c0c0c0;} .eEhwuX::after{content:"";position:absolute;display:none;left:4px;top:2px;width:5px;height:8px;border:solid white;border-width:0 2px 2px 0;-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);}
# /* sc-component-id: sc-jqCOkK */
# .fhVLwy{color:black;font-size:16px;font-weight:400;font-family:'Open Sans',sans-serif;display:inline-block;border:none;border-bottom:1px solid #cfcfcf;background-color:transparent;padding-left:20px;outline:none;box-shadow:none;position:absolute;opacity:0;cursor:pointer;left:0;height:100%;margin:0;line-height:normal;} .fhVLwy:checked ~ .sc-jbKcbu::before{display:block;} .fhVLwy:checked ~ .sc-jbKcbu::after{display:block;left:4px;top:1px;width:5px;height:10px;} .fhVLwy:checked ~ .sc-jbKcbu{background-color:#333333;border:1px solid #333333;} .fhVLwy:checked ~ .sc-jbKcbu{background-color:#1f4985;border:1px solid #1f4985;} .fhVLwy:disabled ~ .sc-jbKcbu{background:#eeeeee;cursor:not-allowed;} .fhVLwy:disabled:checked ~ .sc-jbKcbu{background-color:#1f4985;border:1px solid #1f4985;opacity:0.6;}
# /* sc-component-id: sc-hEsumM */
# .gfrwYo{border-width:1px;border-style:solid;border-radius:50%;border-color:#f1f3f7;background:#f1f3f7;}
# /* sc-component-id: sc-cIShpX */
# .eYJTTK{font-size:13px;margin-left:8px;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){} .eYJTTK em{color:#666666;-webkit-text-decoration:line-through;text-decoration:line-through;font-style:normal;font-weight:600;}
# /* sc-component-id: sc-kafWEX */
# .hnacHk{display:inline-block;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;color:#31812e;background:#effcf5;border:1px solid #31812e;border-radius:16px;font-size:10px;font-weight:500;padding:1px 6px;text-transform:uppercase;}
# /* sc-component-id: sc-feJyhm */
# .vGZum{position:absolute;} @media (max-width:767px){} @media (min-width:768px) and (max-width:991px){} @media (min-width:992px) and (max-width:1199px){} @media (min-width:1200px){} .vGZum .sc-jzJRlG{border-top:1px solid rgb(240,240,240);} .vGZum .sc-jzJRlG:first-child{border-right:1px solid rgb(240,240,240);}
# /* sc-component-id: sc-iELTvK */
# .cGJDvA{width:50%;height:40px;}</style>
# <title data-react-helmet="true">Mobile Phones - Latest Mobiles Online at Best Prices - Reliance Digital</title>
# <meta content="" data-react-helmet="true" name="keywords"><meta content="Buy mobiles online from popular brands such as Apple, Samsung, OnePlus, Vivo and more at Reliance Digital. Get delivery in 3 hours on select mobile phones and pin codes." data-react-helmet="true" name="Description"><meta content="XnuZaT73IOPs_qlSbekjs3VI3pnJ7KJrqm44AnlQews" data-react-helmet="true" name="google-site-verification"><meta content="L4gW9Zs0u0Fi_e1wM-pxn5IF_xmz5t4iAq9gys8m4sE" data-react-helmet="true" name="google-site-verification2"><meta content="INDEX,FOLLOW" data-react-helmet="true" name="robots"><meta content="" data-react-helmet="true" property="og:title"><meta content="341116863058523" data-react-helmet="true" property="fb:app_id"><meta content="" data-react-helmet="true" property="og:url"/><meta content="Reliance Digital" data-react-helmet="true" property="og:site_name"/><meta content="" data-react-helmet="true" property="og:image"/><meta content="en_EN" data-react-helmet="true" property="og:locale"/><meta content="article" data-react-helmet="true" property="og:type"/><meta content="Buy mobiles online from popular brands such as Apple, Samsung, OnePlus, Vivo and more at Reliance Digital. Get delivery in 3 hours on select mobile phones and pin codes." data-react-helmet="true" property="og:description"/><meta content="" data-react-helmet="true" property="product:brand"/><meta content="" data-react-helmet="true" property="product:availability"/><meta content="new" data-react-helmet="true" property="product:condition"/><meta content="" data-react-helmet="true" property="product:price:amount"/><meta content="INR" data-react-helmet="true" property="product:price:currency"/><meta content="" data-react-helmet="true" property="product:retailer_item_id"/><meta content="" data-react-helmet="true" property="product:item_group_id"/><meta content="" data-react-helmet="true" property="product:category"/>
# <script data-react-helmet="true" type="application/ld+json">{"@context":"https://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.reliancedigital.in/samsung-galaxy-a22-128-gb-6-gb-black/p/491997058","name":"Samsung Galaxy A22 128 GB 6 GB Black"},{"@type":"ListItem","position":2,"url":"https://www.reliancedigital.in/samsung-a12-128-gb-4-gb-ram-black-mobile-phone/p/491959401","name":"Samsung A12 128 GB, 4 GB RAM, Black, Mobile Phone"},{"@type":"ListItem","position":3,"url":"https://www.reliancedigital.in/samsung-a12-64-gb-4-gb-ram-blue-mobile-phone/p/491959397","name":"Samsung A12 64 GB, 4 GB RAM, Blue, Mobile Phone"},{"@type":"ListItem","position":4,"url":"https://www.reliancedigital.in/samsung-a12-64-gb-4-gb-ram-white-mobile-phone/p/491959399","name":"Samsung A12 64 GB, 4 GB RAM, White, Mobile Phone"},{"@type":"ListItem","position":5,"url":"https://www.reliancedigital.in/samsung-a12-128-gb-6-gb-ram-blue-mobile-phone/p/491997050","name":"Samsung A12 128 GB, 6 GB RAM, Blue, Mobile Phone"},{"@type":"ListItem","position":6,"url":"https://www.reliancedigital.in/samsung-a12-128-gb-6-gb-ram-black-mobile-phone/p/491997051","name":"Samsung A12 128 GB, 6 GB RAM, Black, Mobile Phone"},{"@type":"ListItem","position":7,"url":"https://www.reliancedigital.in/samsung-a12-128-gb-6-gb-ram-white-mobile-phone/p/491997052","name":"Samsung A12 128 GB, 6 GB RAM, White, Mobile Phone"},{"@type":"ListItem","position":8,"url":"https://www.reliancedigital.in/samsung-a12-128-gb-4-gb-ram-white-mobile-phone/p/491959402","name":"Samsung A12 128 GB, 4 GB RAM, White, Mobile Phone"},{"@type":"ListItem","position":9,"url":"https://www.reliancedigital.in/samsung-a12-128-gb-4-gb-ram-blue-mobile-phone/p/491959400","name":"Samsung A12 128 GB, 4 GB RAM, Blue, Mobile Phone"},{"@type":"ListItem","position":10,"url":"https://www.reliancedigital.in/samsung-a12-64-gb-4-gb-ram-black-mobile-phone/p/491959398","name":"Samsung A12 64 GB, 4 GB RAM, Black, Mobile Phone"}]}</script>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="6HLAC-46T3G-5C4WN-5E4UV-Q72GS",function(){function e(){if(!r){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,o.appendChild(e),r=!0}}function t(e){r=!0;var n,t,a,i,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(o,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",i=(a.frameElement||a).style,i.width=0,i.height=0,i.border=0,i.display="none",o.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void 0;",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=14,window.BOOMR.url=n+"6HLAC-46T3G-5C4WN-5E4UV-Q72GS";var i=document.currentScript||document.getElementsByTagName("script")[0],o=i.parentNode,r=!1,d=document.createElement("link");if(d.relList&&"function"==typeof d.relList.supports&&d.relList.supports("preload")&&"as"in d)window.BOOMR.snippetMethod="p",d.href=window.BOOMR.url,d.rel="preload",d.as="script",d.addEventListener("load",e),d.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!r)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),o.appendChild(d);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="m73qm4vyk34mgysqbysq-f-e1682d673-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"32","ak.cp":"1265198","ak.ai":parseInt("760197",10),"ak.ol":"0","ak.cr":27,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"d727759","ak.r":34477,"ak.a2":n,"ak.m":"dsca","ak.n":"essl","ak.bpcip":"103.247.6.0","ak.cport":1830,"ak.gh":"184.86.248.191","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1649413669","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"19","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></meta></meta></meta></meta></meta></meta></meta></link></link></link></link></link></link></link></link></link></head>
# <body>
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5QTNQC9" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <div class="screen-backdrop">
# <div class="screen-lock-box">
# <div class="lines" data-reactroot=""><div class="bar animateDot"></div><div class="bar animateDot"></div><div class="bar animateDot"></div><div class="bar animateDot"></div></div>
# </div>
# </div>
# <div id="root"><div class="sc-htpNat ieKcal sc-bwzfXH jzNZAg" id="touchslide"><div></div></div><header class=""><ul class="linkInfo no-print"><li class="linkInfo__item">OUR BRAND PROMISE</li><li class="linkInfo__item"><a aria-label="/content/returnsandcancellations" attr-tag="link" href="/content/returnsandcancellations" id="RIL_EasyReturns" rel="noopener noreferrer" target="blank"><i aria-hidden="true" class="icon-EASY-RETURN"></i> <!-- -->EASY RETURN</a></li><li class="linkInfo__item"><i aria-hidden="true" class="icon-DAY-DELIVERY"></i>NEXT DAY DELIVERY</li><li class="linkInfo__item"><a aria-label="/content/resq_services" attr-tag="link" href="/content/resq_services" id="RIL_NextdayDelivery" rel="noopener noreferrer" target="blank"><i aria-hidden="true" class="icon-SERVICE-GUARANTEE-1"></i>SERVICE GUARANTEE</a></li><li class="linkInfo__item"><i aria-hidden="true" class="icon-UNMATCHED-NETWORK-1"></i>UNMATCHED NETWORK</li><li class="linkInfo__item"><a aria-label="/locateus" attr-tag="link" href="/locateus" id="RIL_FindAStore2" rel="noopener noreferrer" target="blank"><i aria-hidden="true" class="fa fa-map-marker"></i> <!-- -->Find a store</a></li><li class="linkInfo__item"><a aria-label="/content/contactus" attr-tag="link" href="/content/contactus" id="RIL_ContactUs2" rel="noopener noreferrer" target="blank">Contact us</a></li></ul><div class="header" id="header"><span id="downloadApp"></span><div class="header__maininfo" id="header__maininfo"><a aria-label="/" attr-tag="link" class="sc-bRBYWo iCsDm" href="/" id="RIL_MainHeaderLogo" target=""><div class="lazy-load-image-background" style="width:150px;height:50px;overflow:visible;position:relative;flex-basis:;padding-top:0;margin:;display:block;background:transparent"><img alt="RelianceDigital Logo" class="" data-srcset="/build/client/images/loaders/rd_logo.svg" id="" src="/build/client/images/loaders/rd_logo.svg" style="margin:;vertical-align:;max-width:;max-height:;display:block;width:150px;height:50px" title="RelianceDigital Logo"/></div></a><div class="searchPanel no-print"><form class="suggestion flex"><div class="suggestion__box" style="background:white"><input autocomplete="off" class="suggestion__input searchPanel__searchBox" id="suggestionBoxEle" placeholder="Find your favorite products" type="text" value=""/></div><button class="searchPanel__search" id="RIL_HomeSearchButton" type="button">Search</button><ul class="suggestion__list"></ul></form></div><ul class="header__maininfo__list no-print"><li class="header__maininfo__list__item"><div class="sc-bxivhb hJDoTy"><div class="sc-bwzfXH sc-csuQGl gCqLPo sc-bxivhb dmrFHq" cursor="pointer"><div class="sc-bwzfXH fqxzzJ sc-bxivhb bcMriR">Select your location</div></div></div></li><li class="header__maininfo__list__item dropdown__cart"><a aria-label="/cart" attr-tag="link" class="pb__24" href="/cart" id="RIL_HeaderCart" target=""><i aria-hidden="true" class="fa fa-shopping-cart header__maininfo__list__item__icon"></i>Cart</a></li><li class="header__maininfo__list__item dropdown__item"><span class="pb__24 pointer" id="RIL_HeaderLoginAndMyAccount"><i aria-hidden="true" class="fa fa-user header__maininfo__list__item__icon"></i>Login</span></li></ul></div><nav><ul class="nav no-print"><li class="nav__container" id="RIL_MobilesTabletsNavigationNode"><div class="nav__title">MOBILES &amp; TABLETS<span class="fa fa-angle-down ml__4"></span></div><div class="nav__description" style="display:none;background-image:url(/build/client/images/loader.gif)"><div class="flex"><div style="cursor:default"><ul><li class="nav__description__item"><a aria-label="/smartphones/c/S101711" attr-tag="link" class="nav__description__hoverULine" href="/smartphones/c/S101711" target="">Smartphones</a></li><li class="nav__description__subitem"><a aria-label="/page/Apple-Iphone-New-Launch" attr-tag="link" class="nav__description__hoverULine" href="/page/Apple-Iphone-New-Launch" target="">Apple New Launch</a></li><li class="nav__description__subitem"><a aria-l ...
# &lt;li&gt;15.81 cm (6.2 inch) (Sub Display)&lt;/li&gt;"><input class="sc-jqCOkK fhVLwy" id="10103914_02_Screen_Size_Diagonal-&lt;li&gt;19.27 cm (7.6 inch) (Main Display)&lt;/li&gt;
# &lt;li&gt;15.81 cm (6.2 inch) (Sub Display)&lt;/li&gt;" name="" type="checkbox"/><span class="sc-hqyNC rZMiY" font-weight="normal"><div class="sc-bxivhb jaGTjb">&lt;li&gt;19.27 cm (7.6 inch) (Main Display)&lt;/li&gt;
# &lt;li&gt;15.81 cm (6.2 inch) (Sub Display)&lt;/li&gt;</div></span><span class="sc-jbKcbu eEhwuX"></span></label></div></div></div><div><div class="sc-bwzfXH lcvyjZ sc-bxivhb hJDoTy"><div class="sc-frDJqD dcQfMc"><label class="sc-kvZOFW fAvZGN" for="10103914_02_Screen_Size_Diagonal-17.53 cm (6.9 inch)"><input class="sc-jqCOkK fhVLwy" id="10103914_02_Screen_Size_Diagonal-17.53 cm (6.9 inch)" name="" type="checkbox"/><span class="sc-hqyNC rZMiY" font-weight="normal"><div class="sc-bxivhb jaGTjb">17.53 cm (6.9 inch)</div></span><span class="sc-jbKcbu eEhwuX"></span></label></div></div></div><div><div class="sc-bwzfXH lcvyjZ sc-bxivhb hJDoTy"><div class="sc-frDJqD dcQfMc"><label class="sc-kvZOFW fAvZGN" for="10103914_02_Screen_Size_Diagonal-17.44 cm (6.9 inch)"><input class="sc-jqCOkK fhVLwy" id="10103914_02_Screen_Size_Diagonal-17.44 cm (6.9 inch)" name="" type="checkbox"/><span class="sc-hqyNC rZMiY" font-weight="normal"><div class="sc-bxivhb jaGTjb">17.44 cm (6.9 inch)</div></span><span class="sc-jbKcbu eEhwuX"></span></label></div></div></div><div><div class="sc-bwzfXH lcvyjZ sc-bxivhb hJDoTy"><div class="sc-frDJqD dcQfMc"><label class="sc-kvZOFW fAvZGN" for="10103914_02_Screen_Size_Diagonal-17.45 cm (6.9 inch)"><input class="sc-jqCOkK fhVLwy" id="10103914_02_Screen_Size_Diagonal-17.45 cm (6.9 inch)" name="" type="checkbox"/><span class="sc-hqyNC rZMiY" font-weight="normal"><div class="sc-bxivhb jaGTjb">17.45 cm (6.9 inch)</div></span><span class="sc-jbKcbu eEhwuX"></span></label></div></div></div><div><div class="sc-bwzfXH lcvyjZ sc-bxivhb hJDoTy"><div class="sc-frDJqD dcQfMc"><label class="sc-kvZOFW fAvZGN" for="10103914_02_Screen_Size_Diagonal-17.27 cm (6.8 Inch)"><input class="sc-jqCOkK fhVLwy" id="10103914_02_Screen_Size_Diagonal-17.27 cm (6.8 Inch)" name="" type="checkbox"/><span class="sc-hqyNC rZMiY" font-weight="normal"><div class="sc-bxivhb jaGTjb">17.27 cm (6.8 Inch)</div></span><span class="sc-jbKcbu eEhwuX"></span></label></div></div></div><div><div class="sc-bwzfXH lcvyjZ sc-bxivhb hJDoTy"><div class="sc-frDJqD dcQfMc"><label class="sc-kvZOFW fAvZGN" for="10103914_02_Screen_Size_Diagonal-17.27 cm (6.8 inch)"><input class="sc-jqCOkK fhVLwy" id="10103914_02_Screen_Size_Diagonal-17.27 cm (6.8 inch)" name="" type="checkbox"/><span class="sc-hqyNC rZMiY" font-weight="normal"><div class="sc-bxivhb jaGTjb">17.27 cm (6.8 inch)</div></span><span class="sc-jbKcbu eEhwuX"></span></label></div></div></div><div><div class="sc-bwzfXH lcvyjZ sc-bxivhb hJDoTy"><div class="sc-frDJqD dcQfMc"><label class="sc-kvZOFW fAvZGN" for="10103914_02_Screen_Size_Diagonal-17.02 cm (6.7 inch)"><input class="sc-jqCOkK fhVLwy" id="10103914_02_Screen_Size_Diagonal-17.02 cm (6.7 inch)" name="" type="checkbox"/><span class="sc-hqyNC rZMiY" font-weight="normal"><div class="sc-bxivhb jaGTjb">17.02 cm (6.7 inch)</div></span><span class="sc-jbKcbu eEhwuX"></span></label></div></div></div><div><div class="sc-bwzfXH lcvyjZ sc-bxivhb hJDoTy"><div class="sc-frDJqD dcQfMc"><label class="sc-kvZOFW fAvZGN" for="10103914_02_Screen_Size_Diagonal-17.01 cm (6.7 inch)"><input class="sc-jqCOkK fhVLwy" id="10103914_02_Screen_Size_Diagonal-17.01 cm (6.7 inch)" name="" type="checkbox"/><span class="sc-hqyNC rZMiY" font-weight="normal"><div class="sc-bxivhb jaGTjb">17.01 cm (6.7 inch)</div></span><span class="sc-jbKcbu eEhwuX"></span></label></div></div></div><div><div class="sc-bwzfXH lcvyjZ sc-bxivhb hJDoTy"><div class="sc-frDJqD dcQfMc"><label class="sc-kvZOFW fAvZGN" for="10103914_02_Screen_Size_Diagonal-17.08 cm (6.7 inch)"><input class="sc-jqCOkK fhVLwy" id="10103914_02_Screen_Size_Diagonal-17.08 cm (6.7 inch)" name="" type="checkbox"/><span class="sc-hqyNC rZMiY" font-weight="normal"><div class="sc-bxivhb jaGTjb">17.08 cm (6.7 inch)</div></span><span class="sc-jbKcbu eEhwuX"></span></label></div></div></div><div><div class="sc-bwzfXH lcvyjZ sc-bxivhb hJDoTy"><div class="sc-frDJqD dcQfMc"><label class="sc-kvZOFW fAvZGN" for="10103914_02_Screen_Size_Diagonal-16.95 ...
# 11.0pt;margin-left:0cm"><span style="font-size: small;"><b style="mso-bidi-font-weight:normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">Buy All Smartphones Online in India</span></b></span><b style="mso-bidi-font-weight:normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></b></p><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
# 11.0pt;margin-left:0cm;text-align:justify"><span style="font-size: small;"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">Mobile phones have transformed from being a device to make calls or send texts, to an entertainment and information gadget. Today, it’s practically impossible to spend a moment without our smartphones by our side- whether it’s just for sending an email, storing important files, doing a video call with our loved ones, or streaming the latest web series while commuting. Mobile phones come with a wide range of features these days- like fascinating photo filters, AI-powered cameras, blazing fast processing speeds, etc. At Reliance Digital, you can compare and find your choice of mobile phone online at the best prices.</span></span><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></p><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
# 11.0pt;margin-left:0cm;text-align:justify"><span style="font-size: small;"><b style="mso-bidi-font-weight:normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">Choosing A Smartphone As Per Operating System</span></b></span><b style="mso-bidi-font-weight:normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></b></p><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
# 11.0pt;margin-left:0cm;text-align:justify;background:white"><span style="font-size: small;"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">With hundreds of options available, the online mobile shopping experience can be quite overwhelming if you don’t know what you want. Begin with choosing the type of operating system you’d be comfortable using. There are only two smartphone operating systems worth considering: Android and iOS.</span></span><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></p><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
# 11.0pt;margin-left:0cm;text-align:justify;background:white"><span style="font-size: small;"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">Here’s a comparison between Android phones and iOS phones that can help you choose better:</span></span><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></p><table border="1" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="border-collapse:collapse;mso-table-layout-alt:fixed;border:none;
#  mso-yfti-tbllook:1536;mso-padding-alt:0cm 5.4pt 0cm 5.4pt;mso-border-insideh:
#  cell-none;mso-border-insidev:cell-none" width="0"> <tbody><tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes;height:43.0pt"> <td style="width:144.75pt;border:solid black 1.0pt;
#   padding:5.0pt 5.0pt 5.0pt 5.0pt;height:43.0pt" valign="top" width="193"><p align="center" class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;
#   margin-bottom:11.0pt;margin-left:0cm;text-align:center"><span style="font-size: small;"><b style="mso-bidi-font-weight:
#   normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">Features</span></b></span><b style="mso-bidi-font-weight:
#   normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></b></p></td> <td style="width:153.0pt;border:solid black 1.0pt;
#   border-left:none;padding:5.0pt 5.0pt 5.0pt 5.0pt;height:43.0pt" valign="top" width="204"><p align="center" class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;
#   margin-bottom:11.0pt;margin-left:0cm;text-align:center"><span style="font-size: small;"><b style="mso-bidi-font-weight:
#   normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">Android</span></b></span><b style="mso-bidi-font-weight:
#   normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></b></p></td> <td style="width:143.25pt;border:solid black 1.0pt;
#   border-left:none;padding:5.0pt 5.0pt 5.0pt 5.0pt;height:43.0pt" valign="top" width="191"><p align="center" class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;
#   margin-bottom:11.0pt;margin-left:0cm;text-align:center"><span style="font-size: small;"><b style="mso-bidi-font-weight:
#   normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">iOS</span></b></span><b style="mso-bidi-font-weight:
#   normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></b></p></td> </tr> <tr style="mso-yfti-irow:1;height:58.0pt"> <td style="width:144.75pt;border:solid black 1.0pt;
#   border-top:none;padding:5.0pt 5.0pt 5.0pt 5.0pt;height:58.0pt" valign="top" width="193"><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
#   11.0pt;margin-left:0cm"><span style="font-size: small;"><b style="mso-bidi-font-weight:normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">Latest   Stable Release</span></b></span><b style="mso-bidi-font-weight:normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></b></p></td> <td style="width:153.0pt;border-top:none;border-left:
#   none;border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;
#   padding:5.0pt 5.0pt 5.0pt 5.0pt;height:58.0pt" valign="top" width="204"><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
#   11.0pt;margin-left:0cm"><span style="font-size: small;"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">Android 10</span></span><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></p></td> <td style="width:143.25pt;border-top:none;border-left:
#   none;border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;
#   padding:5.0pt 5.0pt 5.0pt 5.0pt;height:58.0pt" valign="top" width="191"><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
#   11.0pt;margin-left:0cm"><span style="font-size: small;"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">iOS 13.3.1 and iPadOS 13.3.1</span></span><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></p><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
#   11.0pt;margin-left:0cm"><span style="font-size: small;"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"> </span></span><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></p></td> </tr> <tr style="mso-yfti-irow:2;height:35.5pt"> <td style="width:144.75pt;border:solid black 1.0pt;
#   border-top:none;padding:5.0pt 5.0pt 5.0pt 5.0pt;height:35.5pt" valign="top" width="193"><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
#   11.0pt;margin-left:0cm"><span style="font-size: small;"><b style="mso-bidi-font-weight:normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">Customizability</span></b></span><b style="mso-bidi-font-weight:normal"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></b></p></td> <td style="width:153.0pt;border-top:none;border-left:
#   none;border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;
#   padding:5.0pt 5.0pt 5.0pt 5.0pt;height:35.5pt" valign="top" width="204"><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
#   11.0pt;margin-left:0cm"><span style="font-size: small;"><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;">A lot. Can change almost anything.</span></span><span lang="EN" style="line-height: 115%; font-family: Calibri, sans-serif; background: white;"><o:p></o:p></span></p></td> <td style="width:143.25pt;border-top:none;border-left:
#   none;border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;
#   padding:5.0pt 5.0pt 5.0pt 5.0pt;height:35.5pt" valign="top" width="191"><p class="MsoNormal" style="margin-top:11.0pt;margin-right:0cm;margin-bottom:
# ...
# text-align:start;widows: 2;-webkit-text-stroke-width: 0px;text-decoration-thickness: initial;
# text-decoration-style: initial;text-decoration-color: initial;word-spacing:
# 0px"> </p><p style="font-variant-ligatures: normal;font-variant-caps: normal;orphans: 2;
# text-align:start;widows: 2;-webkit-text-stroke-width: 0px;text-decoration-thickness: initial;
# text-decoration-style: initial;text-decoration-color: initial;word-spacing:
# 0px"><span style="font-size: small;"><strong><span style="font-family: Arial, sans-serif; color: black;">Popular Searches on Battery Capacity for Mobile Phones:</span></strong></span><span style="font-family: Arial, sans-serif; color: black;"><o:p></o:p></span></p><p style="font-variant-ligatures: normal;font-variant-caps: normal;orphans: 2;
# text-align:start;widows: 2;-webkit-text-stroke-width: 0px;text-decoration-thickness: initial;
# text-decoration-style: initial;text-decoration-color: initial;word-spacing:
# 0px"><strong><span style="font-family: Arial, sans-serif; color: black; font-weight: normal;"><a href="https://www.reliancedigital.in/page/5000-mah-battery-mobiles"><span style="font-size: small;">5000 mAh Battery Mobiles</span></a></span><span style="font-size: small;"><span style="font-family: Arial, sans-serif; color: black; font-weight: normal;"> | </span></span><span style="font-family: Arial, sans-serif; color: black; font-weight: normal;"><a href="https://www.reliancedigital.in/page/6000-mah-battery-mobiles"><span style="font-size: small;">6000 mAh Battery Mobiles</span></a></span><span style="font-size: small;"><span style="font-family: Arial, sans-serif; color: black; font-weight: normal;"> | </span></span><span style="font-family: Arial, sans-serif; color: black; font-weight: normal;"><a href="https://www.reliancedigital.in/page/7000-mah-battery-mobiles"><span style="font-size: small;">7000 mAh Battery Mobiles</span></a></span></strong></p><p style="font-variant-ligatures: normal;font-variant-caps: normal;orphans: 2;
# text-align:start;widows: 2;-webkit-text-stroke-width: 0px;text-decoration-thickness: initial;
# text-decoration-style: initial;text-decoration-color: initial;word-spacing:
# 0px"> </p><p style="font-variant-ligatures: normal;font-variant-caps: normal;orphans: 2;
# text-align:start;widows: 2;-webkit-text-stroke-width: 0px;text-decoration-thickness: initial;
# text-decoration-style: initial;text-decoration-color: initial;word-spacing:
# 0px"><span style="font-size: small;"><strong><span style="font-family: Arial, sans-serif; color: black;">Popular Searches on Operating System for Mobile Phones:</span></strong></span><span style="font-family: Arial, sans-serif; color: black;"><o:p></o:p></span></p><p style="font-variant-ligatures: normal;font-variant-caps: normal;orphans: 2;
# text-align:start;widows: 2;-webkit-text-stroke-width: 0px;text-decoration-thickness: initial;
# text-decoration-style: initial;text-decoration-color: initial;word-spacing:
# 0px"><span style="font-size: x-small;"><span style="font-family: Arial, sans-serif; color: black;"><a href="https://www.reliancedigital.in/page/android-mobiles"><span style="font-size: small;">Android Mobiles</span></a></span></span><span style="font-size: small;"><br/></span></p><p style="font-variant-ligatures: normal;font-variant-caps: normal;orphans: 2;
# text-align:start;widows: 2;-webkit-text-stroke-width: 0px;text-decoration-thickness: initial;
# text-decoration-style: initial;text-decoration-color: initial;word-spacing:
# 0px"> </p><p style="font-variant-ligatures: normal;font-variant-caps: normal;orphans: 2;
# text-align:start;widows: 2;-webkit-text-stroke-width: 0px;text-decoration-thickness: initial;
# text-decoration-style: initial;text-decoration-color: initial;word-spacing:
# 0px"><span style="font-size: small;"><strong><span style="font-family: Arial, sans-serif; color: black;">Other Popular Searches on Mobiles:</span></strong></span><span style="font-family: Arial, sans-serif; color: black;"><o:p></o:p></span></p><p class="MsoNormal" style="mso-margin-top-alt:auto;mso-margin-bottom-alt:auto"><span style="font-size: x-small;"><span style="line-height: 107%; font-family: Arial, sans-serif; color: black;"><a href="https://www.reliancedigital.in/page/gaming-mobiles"><span style="font-size: small;"><span style="line-height: 107%;">Gaming Mobiles</span></span></a></span></span><span style="font-size: small;"><span style="font-family: Arial, sans-serif; color: black;"> | </span></span><span style="font-size: small;"><span style="line-height: 107%; font-family: Arial, sans-serif; color: black;"><a href="https://www.reliancedigital.in/page/gaming-mobiles-under-15000"><span style="line-height: 107%;">Gaming Mobiles Under 15000</span></a></span><span style="font-family: Arial, sans-serif; color: black;"> | </span></span><span style="font-size: small;"><span style="line-height: 107%; font-family: Arial, sans-serif; color: black;"><a href="https://www.reliancedigital.in/page/6gb-ram-128gb-rom-mobiles"><span style="line-height: 107%;">6GB RAM 128 GB ROM Mobiles</span></a></span><span style="font-family: Arial, sans-serif; color: black;"> | </span></span><span style="font-size: small;"><span style="line-height: 107%; font-family: Arial, sans-serif; color: black;"><a href="https://www.reliancedigital.in/page/apple-iphones-dual-sim"><span style="line-height: 107%;">Dual SIM Apple iPhones</span></a> | </span></span><a href="https://www.reliancedigital.in/page/108mp-camera-phones" style="font-family: Arial, sans-serif;"><span style="font-size: small;">108MP Camera Phones</span></a></p><p class="MsoNormal"><o:p></o:p></p></div></div><div><h2 class="ml__8" itemprop="name">Smartphones<!-- --> <!-- -->Price List</h2><table class="priceListTable"><tbody><tr class="priceListTable__row"><th class="priceListTable__header">S.no</th><th class="priceListTable__header">Products - Smartphones</th><th class="priceListTable__header">Price</th></tr><tr class="priceListTable__row"><td class="priceListTable__data">1</td><td class="priceListTable__data"><a aria-label="/samsung-galaxy-a22-128-gb-6-gb-black/p/491997058" attr-tag="link" href="/samsung-galaxy-a22-128-gb-6-gb-black/p/491997058" target="">Samsung Galaxy A22 128 GB 6 GB Black</a></td><td class="priceListTable__data"><span>₹</span><span>18,499.00</span></td></tr><tr class="priceListTable__row"><td class="priceListTable__data">2</td><td class="priceListTable__data"><a aria-label="/samsung-a12-128-gb-4-gb-ram-black-mobile-phone/p/491959401" attr-tag="link" href="/samsung-a12-128-gb-4-gb-ram-black-mobile-phone/p/491959401" target="">Samsung A12 128 GB, 4 GB RAM, Black, Mobile Phone</a></td><td class="priceListTable__data"><span>₹</span><span>13,999.00</span></td></tr><tr class="priceListTable__row"><td class="priceListTable__data">3</td><td class="priceListTable__data"><a aria-label="/samsung-a12-64-gb-4-gb-ram-blue-mobile-phone/p/491959397" attr-tag="link" href="/samsung-a12-64-gb-4-gb-ram-blue-mobile-phone/p/491959397" target="">Samsung A12 64 GB, 4 GB RAM, Blue, Mobile Phone</a></td><td class="priceListTable__data"><span>₹</span><span>12,999.00</span></td></tr><tr class="priceListTable__row"><td class="priceListTable__data">4</td><td class="priceListTable__data"><a aria-label="/samsung-a12-64-gb-4-gb-ram-white-mobile-phone/p/491959399" attr-tag="link" href="/samsung-a12-64-gb-4-gb-ram-white-mobile-phone/p/491959399" target="">Samsung A12 64 GB, 4 GB RAM, White, Mobile Phone</a></td><td class="priceListTable__data"><span>₹</span><span>12,999.00</span></td></tr><tr class="priceListTable__row"><td class="priceListTable__data">5</td><td class="priceListTable__data"><a aria-label="/samsung-a12-128-gb-6-gb-ram-blue-mobile-phone/p/491997050" attr-tag="link" href="/samsung-a12-128-g ...
# <div id="player" style="position: absolute; top: -9999px; left: -9999px;"></div>
# <script>window.__INITIAL_STATE__ = {"$test":{"testParams":{"test_source":"","test_medium":"","test_campaign":""}},"$home":{"isContentLoaded":false,"componentOrder":[{"section":"section8","order":1,"type":"SearchBanner"},{"section":"section5","order":2,"type":"fiveSliderProductCarousel"}],"section1":[],"section2":[],"section3":[],"section4":[],"section5":[{"componentType":"comp_0000109L","visible":true,"name":"Deals of the day","displayName":"Deals of the day","viewAllUrl":"/","bannerPosition":"right","banners":[],"data":[{"name":"Apple iPhone 7 Plus Smart Phone 32 GB, Silver","imageUrl":"","altText":"Apple iPhone 7 Plus Smart Phone 32 GB, Silver","url":"/","mrp":"62840","sellingPrice":"49900","discount":"21%(₹12,940)","deal":false,"inStock":true,"hasPP":false,"teaserType":null},{"name":"Apple iPhone 7 Plus Smart Phone 32 GB, Silver","imageUrl":"","altText":"Apple iPhone 7 Plus Smart Phone 32 GB, Silver","url":"/","mrp":"62840","sellingPrice":"49900","discount":"21%(₹12,940)","deal":false,"inStock":true,"hasPP":false,"teaserType":null},{"name":"Apple iPhone 7 Plus Smart Phone 32 GB, Silver","imageUrl":"","altText":"Apple iPhone 7 Plus Smart Phone 32 GB, Silver","url":"/","mrp":"62840","sellingPrice":"49900","discount":"21%(₹12,940)","deal":false,"inStock":true,"hasPP":false,"teaserType":null},{"name":"Sandisk Ultra M3.0 Pen Drive, 16 GB","imageUrl":"","altText":"Sandisk Ultra M3.0 Pen Drive, 16 GB","url":"/","mrp":"900","sellingPrice":"799","discount":"11%(₹101)","deal":false,"inStock":true,"hasPP":false,"teaserType":null,"preOrderEnabled":false,"preOrderDetails":null},{"name":"Sony MDR-XB950BT Wireless Headphone, Black","imageUrl":"","altText":"Sony MDR-XB950BT Wireless Headphone, Black","url":"/","mrp":"12990","sellingPrice":"10990","discount":"15%(₹2,000)","deal":false,"inStock":true,"hasPP":false,"teaserType":null,"preOrderEnabled":true,"preOrderDetails":{"preLaunchDate":1552285818000,"preOrderStartDate":1552564891000,"preOrderEndDate":1554033687000,"preOrderMsg":"delivery from tommorow","priceVisibility":false}}]},{"componentType":"comp_000003V2","visible":true,"name":"NEW ARRIVALS","displayName":"NEW ARRIVALS","viewAllUrl":"/search?q=:relevance:productTags:TEST_1","bannerPosition":null,"banners":[],"data":[{"name":"Samsung 123Series 5 UA49K5300AR Full HD Smart LED TV, 124.46 cm (49)","imageUrl":"","altText":"Samsung 123Series 5 UA49K5300AR Full HD Smart LED TV, 124.46 cm (49)","url":"/","mrp":"64990","sellingPrice":"60000","discount":"8%(₹4,990)","deal":false,"inStock":true,"hasPP":false,"teaserType":"NEW","preOrderEnabled":false,"preOrderDetails":null},{"name":"Sony MDR-XB950BT Wireless Headphone, Black","imageUrl":"","altText":"Sony MDR-XB950BT Wireless Headphone, Black","url":"/","mrp":"12990","sellingPrice":"10990","discount":"15%(₹2,000)","deal":false,"inStock":true,"hasPP":false,"teaserType":null,"preOrderEnabled":true,"preOrderDetails":{"preLaunchDate":1552285818000,"preOrderStartDate":1552564891000,"preOrderEndDate":1554033687000,"preOrderMsg":"delivery from tommorow","priceVisibility":false}},{"name":"Sandisk Ultra M3.0 Pen Drive, 16 GB","imageUrl":"","altText":"Sandisk Ultra M3.0 Pen Drive, 16 GB","url":"/","mrp":"900","sellingPrice":"799","discount":"11%(₹101)","deal":false,"inStock":true,"hasPP":false,"teaserType":null,"preOrderEnabled":false,"preOrderDetails":null},{"name":"Samsung 123Series 5 UA49K5300AR Full HD Smart LED TV, 124.46 cm (49)","imageUrl":"","altText":"Samsung 123Series 5 UA49K5300AR Full HD Smart LED TV, 124.46 cm (49)","url":"/","mrp":"64990","sellingPrice":"60000","discount":"8%(₹4,990)","deal":false,"inStock":true,"hasPP":false,"teaserType":"NEW","preOrderEnabled":false,"preOrderDetails":null},{"name":"Usha Janome Wonder Stitch Automatic Zig Zag Sewing Machine","imageUrl":"","altText":"Usha Janome Wonder Stitch Automatic Zig Zag Sewing Machine","url":"/","mrp":"12000","sellingPrice":"11900","discount":"1%(₹100)","deal":false,"inStock":true,"hasPP":false,"teaserType":null,"preOrderEnabled":t ...
# <script>window.device = "pc"</script>
# <script nomodule="" src="/build/client/js/cored1eeb66f.js"></script>
# <script nomodule="" src="/build/client/js/obserPoly0e4afc9e.js"></script>
# <script>
#         window.addEventListener('load', function(){
#           const scrpt426727 = document.createElement('script');scrpt426727.defer = true;scrpt426727.src = "/build/client/js/vendor1e0369bd6.js";document.head.appendChild(scrpt426727);
#           const scrpt426728 = document.createElement('script');scrpt426728.defer = true;scrpt426728.src = "/build/client/js/vendor295434489.js";document.head.appendChild(scrpt426728);
#           const scrpt426729 = document.createElement('script');scrpt426729.defer = true;scrpt426729.src = "/build/client/js/AutoSuggestf52acbb4.js";document.head.appendChild(scrpt426729);const scrpt426730 = document.createElement('script');scrpt426730.defer = true;scrpt426730.src = "/build/client/js/ProductLandingPageWd5779d6e.js";document.head.appendChild(scrpt426730);
#           const scrpt426731 = document.createElement('script');scrpt426731.defer = true;scrpt426731.src = "/build/client/js/clientWebfbdf9339.js";document.head.appendChild(scrpt426731);
#         });
#       </script>
# <script>
#         "serviceWorker" in window.navigator && window.addEventListener("load",function(){window.navigator.serviceWorker.register("/sw.js").then(function (r) { let serviceWorker; if (r.installing) { serviceWorker = r.installing; } else if (r.waiting) { serviceWorker = r.waiting; } else if (r.active) { serviceWorker = r.active; } if (serviceWorker) { serviceWorker.addEventListener("statechange", function(e) { /*console.log("sw current state", serviceWorker.state);*/ if (e.target.state === "activated") { r.pushManager.subscribe({ userVisibleOnly: true }).then(function(p) { /*console.log(p); console.log("push nortification activated");*/ }, function(error) { console.log(error); });  } }); } }).catch(function(e){console.error("ServiceWorker registration failed: ",e);});});
#         var installPromptEvent;window.addEventListener("beforeinstallprompt",function(e){installPromptEvent = e; document.querySelector("#downloadApp").style.visibility = "visible";/*console.log("beforeinstallprompt Event fired", installPromptEvent);*/document.querySelector("#downloadApp").addEventListener("click",function(){installPromptEvent && installPromptEvent.prompt(); }),e.userChoice.then(function(e){("dismissed"===e.outcome || e === undefined)?(console.log("User cancelled home screen install")):(document.querySelector("#downloadApp").style.visibility = "hidden",console.log("User added to home screen"))})});
#       </script>
# <script type="application/ld+json">{"@context": "http://schema.org","@type": "WebSite","url": "https://www.reliancedigital.in/","potentialAction": {"@type": "SearchAction","target": "https://www.reliancedigital.in/search?q={search_term_string}","query-input": "required name=search_term_string"}}</script>
# </body>
# </html>

# %% [markdown]
# Now we have all HTML elements

# %% [markdown]
# ### Results

# %%
result = soup.find_all('li',{'class': 'grid pl__container__sp blk__lg__3 blk__md__4 blk__sm__6 blk__xs__6'})

# %%
len(result)
# Out:
# 24

# %% [markdown]
# ### Targeting Necessary Data

# %% [markdown]
# ### Mobile Name

# %%
result[0].find('p',{'class':'sp__name'}).get_text()
# Out:
# 'Samsung Galaxy A22 128 GB 6 GB Black'

# %% [markdown]
# ### Price

# %%
result[0].find('span',{'class':'sc-bxivhb dmBTBc'}).get_text()
# Out:
# '₹18,499.00'

# %% [markdown]
# ### URL

# %%
# Combining url part 1 with url part 2 in order to get the absolute url

Url_part_1 = "https://www.reliancedigital.in/"

# %%
Url_part_2 = []

for item in result:
    for link in item.find_all('a',{'attr-tag':'link'}):
        Url_part_2.append(link.get('href'))

# %%
Url_part_2
# Out:
# ['/samsung-galaxy-a22-128-gb-6-gb-black/p/491997058',
#  '/samsung-a12-128-gb-4-gb-ram-black-mobile-phone/p/491959401',
#  '/samsung-a12-64-gb-4-gb-ram-blue-mobile-phone/p/491959397',
#  '/samsung-a12-64-gb-4-gb-ram-white-mobile-phone/p/491959399',
#  '/samsung-a12-128-gb-6-gb-ram-blue-mobile-phone/p/491997050',
#  '/samsung-a12-128-gb-6-gb-ram-black-mobile-phone/p/491997051',
#  '/samsung-a12-128-gb-6-gb-ram-white-mobile-phone/p/491997052',
#  '/samsung-a12-128-gb-4-gb-ram-white-mobile-phone/p/491959402',
#  '/samsung-a12-128-gb-4-gb-ram-blue-mobile-phone/p/491959400',
#  '/samsung-a12-64-gb-4-gb-ram-black-mobile-phone/p/491959398',
#  '/samsung-galaxy-a22-128-gb-6-gb-mint/p/491997057',
#  '/samsung-galaxy-a51-128-gb-6-gb-ram-prism-white-mobile-phone/p/491615781',
#  '/samsung-galaxy-s10-mobile-phone-512-gb-8-gb-ram-prism-white/p/491550805',
#  '/samsung-galaxy-s10-mobile-phone-512-gb-8-gb-ram-ceramic-black/p/491550809',
#  '/samsung-galaxy-s10-mobile-phone-128-gb-8-gb-ram-prism-blue/p/491550802',
#  '/samsung-galaxy-s10-mobile-phone-128-gb-8-gb-ram-prism-white/p/491550804',
#  '/samsung-galaxy-s10-mobile-phone-128-gb-8-gb-ram-prism-black/p/491550803',
#  '/samsung-galaxy-a10s-32-gb-2-gb-ram-black-mobile-phone/p/491584549',
#  '/samsung-galaxy-a20s-64-gb-4-gb-ram-black-mobile-phone/p/491615029',
#  '/samsung-s20-plus-128-gb-8-gb-ram-cosmic-black-mobile-phone/p/491666906',
#  '/samsung-s20-plus-128-gb-8-gb-ram-cloud-blue-mobile-phone/p/491666904',
#  '/samsung-galaxy-a51-128-gb-6-gb-ram-prism-blue-mobile-phone/p/491615779',
#  '/samsung-a70s-128-gb-6-gb-ram-prism-crush-white-mobile-phone/p/491615032',
#  '/samsung-a70s-128-gb-8-gb-ram-prism-crush-black-mobile-phone/p/491615033']

# %% [markdown]
# ### Join Url1 & Url2

# %%
Homepage = []

for link_2 in Url_part_2:
    Homepage.append(urllib.parse.urljoin(Url_part_1, link_2))

# %%
Homepage
# Out:
# ['https://www.reliancedigital.in/samsung-galaxy-a22-128-gb-6-gb-black/p/491997058',
#  'https://www.reliancedigital.in/samsung-a12-128-gb-4-gb-ram-black-mobile-phone/p/491959401',
#  'https://www.reliancedigital.in/samsung-a12-64-gb-4-gb-ram-blue-mobile-phone/p/491959397',
#  'https://www.reliancedigital.in/samsung-a12-64-gb-4-gb-ram-white-mobile-phone/p/491959399',
#  'https://www.reliancedigital.in/samsung-a12-128-gb-6-gb-ram-blue-mobile-phone/p/491997050',
#  'https://www.reliancedigital.in/samsung-a12-128-gb-6-gb-ram-black-mobile-phone/p/491997051',
#  'https://www.reliancedigital.in/samsung-a12-128-gb-6-gb-ram-white-mobile-phone/p/491997052',
#  'https://www.reliancedigital.in/samsung-a12-128-gb-4-gb-ram-white-mobile-phone/p/491959402',
#  'https://www.reliancedigital.in/samsung-a12-128-gb-4-gb-ram-blue-mobile-phone/p/491959400',
#  'https://www.reliancedigital.in/samsung-a12-64-gb-4-gb-ram-black-mobile-phone/p/491959398',
#  'https://www.reliancedigital.in/samsung-galaxy-a22-128-gb-6-gb-mint/p/491997057',
#  'https://www.reliancedigital.in/samsung-galaxy-a51-128-gb-6-gb-ram-prism-white-mobile-phone/p/491615781',
#  'https://www.reliancedigital.in/samsung-galaxy-s10-mobile-phone-512-gb-8-gb-ram-prism-white/p/491550805',
#  'https://www.reliancedigital.in/samsung-galaxy-s10-mobile-phone-512-gb-8-gb-ram-ceramic-black/p/491550809',
#  'https://www.reliancedigital.in/samsung-galaxy-s10-mobile-phone-128-gb-8-gb-ram-prism-blue/p/491550802',
#  'https://www.reliancedigital.in/samsung-galaxy-s10-mobile-phone-128-gb-8-gb-ram-prism-white/p/491550804',
#  'https://www.reliancedigital.in/samsung-galaxy-s10-mobile-phone-128-gb-8-gb-ram-prism-black/p/491550803',
#  'https://www.reliancedigital.in/samsung-galaxy-a10s-32-gb-2-gb-ram-black-mobile-phone/p/491584549',
#  'https://www.reliancedigital.in/samsung-galaxy-a20s-64-gb-4-gb-ram-black-mobile-phone/p/491615029',
#  'https://www.reliancedigital.in/samsung-s20-plus-128-gb-8-gb-ram-cosmic-black-mobile-phone/p/491666906',
#  'https://www.reliancedigital.in/samsung-s20-plus-128-gb-8-gb-ram-cloud-blue-mobile-phone/p/491666904',
#  'https://www.reliancedigital.in/samsung-galaxy-a51-128-gb-6-gb-ram-prism-blue-mobile-phone/p/491615779',
#  'https://www.reliancedigital.in/samsung-a70s-128-gb-6-gb-ram-prism-crush-white-mobile-phone/p/491615032',
#  'https://www.reliancedigital.in/samsung-a70s-128-gb-8-gb-ram-prism-crush-black-mobile-phone/p/491615033']

# %% [markdown]
# ### Append all result in List Comprenhension

# %%
Mobile = [result.find('p',{'class':'sp__name'}).get_text() for result in result]
Price = [result.find('span',{'class':'sc-bxivhb dmBTBc'}).get_text() for result in result]

# %%
len(Price)
# Out:
# 24

# %% [markdown]
# ### Create padas dataframe

# %%
df = pd.DataFrame({'Mobile':Mobile,'Price':Price,})
df
# Out:
#                                                Mobile       Price
# 0                Samsung Galaxy A22 128 GB 6 GB Black  ₹18,499.00
# 1   Samsung A12 128 GB, 4 GB RAM, Black, Mobile Phone  ₹13,999.00
# 2     Samsung A12 64 GB, 4 GB RAM, Blue, Mobile Phone  ₹12,999.00
# 3    Samsung A12 64 GB, 4 GB RAM, White, Mobile Phone  ₹12,999.00
# 4    Samsung A12 128 GB, 6 GB RAM, Blue, Mobile Phone  ₹15,499.00
# 5   Samsung A12 128 GB, 6 GB RAM, Black, Mobile Phone  ₹15,499.00
# 6   Samsung A12 128 GB, 6 GB RAM, White, Mobile Phone  ₹15,499.00
# 7   Samsung A12 128 GB, 4 GB RAM, White, Mobile Phone  ₹13,999.00
# 8    Samsung A12 128 GB, 4 GB RAM, Blue, Mobile Phone  ₹13,999.00
# 9    Samsung A12 64 GB, 4 GB RAM, Black, Mobile Phone  ₹12,999.00
# 10                Samsung Galaxy A22 128 GB 6 GB Mint  ₹18,499.00
# 11  Samsung Galaxy A51, 128 GB, 6 GB RAM, Prism Wh...  ₹20,999.00
# 12  Samsung Galaxy S10 Mobile Phone 512 GB, 8 GB R...  ₹71,400.00
# 13  Samsung Galaxy S10+ Mobile Phone 512 GB, 8 GB ...  ₹78,800.00
# 14  Samsung Galaxy S10 Mobile Phone 128 GB, 8 GB R...  ₹58,800.00
# 15  Samsung Galaxy S10 Mobile Phone 128 GB, 8 GB R...  ₹58,800.00
# 16  Samsung Galaxy S10 Mobile Phone 128 GB, 8 GB R...  ₹58,800.00
# 17  Samsung Galaxy A10s 32 GB, 2 GB RAM, Black, Mo...   ₹9,840.00
# 18  Samsung Galaxy A20s 64 GB, 4 GB RAM, Black, Mo...  ₹13,695.00
# 19  Samsung S20 Plus 128 GB, 8 GB RAM, Cosmic Blac...  ₹69,999.00
# 20  Samsung S20 Plus 128 GB, 8 GB RAM, Cloud Blue,...  ₹69,999.00
# 21  Samsung Galaxy A51, 128 GB, 6 GB RAM, Prism Bl...  ₹20,999.00
# 22  Samsung A70s 128 GB, 6 GB RAM, Prism Crush Whi...  ₹28,400.00
# 23  Samsung A70s 128 GB, 8 GB RAM, Prism Crush Bla...  ₹30,500.00

# %% [markdown]
# ### putting all Together

# %%
#creating empty datafrme
df = pd.DataFrame(columns=['Mobile','Price','Homepage'])

for i in range(1,10):

    #website request
    Website = 'https://www.reliancedigital.in/smart-phones/c/S101711?searchQuery=Samsung&page' + str(i)
    
    response = requests.get(Website)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    #results item
    result = soup.find_all('li',{'class': 'grid pl__container__sp blk__lg__3 blk__md__4 blk__sm__6 blk__xs__6'})

    #url part 1
    Url_part_1 = "https://www.reliancedigital.in/"
    
    #url part 2
    Url_part_2 = []
    
    for item in result:
        for link in item.find_all('a',{'attr-tag':'link'}):
            Url_part_2.append(link.get('href'))
    #Combining url part 1 with url part 2 in order to get the absolute url
    Homepage = []

    for link_2 in Url_part_2:
        Homepage.append(urllib.parse.urljoin(Url_part_1, link_2))
    
    Mobile = [result.find('p',{'class':'sp__name'}).get_text() for result in result]
    Price = [result.find('span',{'class':'sc-bxivhb dmBTBc'}).get_text() for result in result]
    
    for k in range(len(Mobile)):
        df = df.append({'Mobile':Mobile[k],'Price':Price[k],'Homepage':Homepage[k]},ignore_index=True)

# %%
df
# Out:
#                                                 Mobile       Price  \
# 0                 Samsung Galaxy A22 128 GB 6 GB Black  ₹18,499.00
# 1    Samsung A12 128 GB, 4 GB RAM, Black, Mobile Phone  ₹13,999.00
# 2      Samsung A12 64 GB, 4 GB RAM, Blue, Mobile Phone  ₹12,999.00
# 3     Samsung A12 64 GB, 4 GB RAM, White, Mobile Phone  ₹12,999.00
# 4     Samsung A12 128 GB, 6 GB RAM, Blue, Mobile Phone  ₹15,499.00
# ..                                                 ...         ...
# 211  Samsung S20 Plus 128 GB, 8 GB RAM, Cosmic Blac...  ₹69,999.00
# 212  Samsung S20 Plus 128 GB, 8 GB RAM, Cloud Blue,...  ₹69,999.00
# 213  Samsung Galaxy A51, 128 GB, 6 GB RAM, Prism Bl...  ₹20,999.00
# 214  Samsung A70s 128 GB, 6 GB RAM, Prism Crush Whi...  ₹28,400.00
# 215  Samsung A70s 128 GB, 8 GB RAM, Prism Crush Bla...  ₹30,500.00
#
#                                               Homepage
# 0    https://www.reliancedigital.in/samsung-galaxy-...
# 1    https://www.reliancedigital.in/samsung-a12-128...
# 2    https://www.reliancedigital.in/samsung-a12-64-...
# 3    https://www.reliancedigital.in/samsung-a12-64-...
# 4    https://www.reliancedigital.in/samsung-a12-128...
# ..                                                 ...
# 211  https://www.reliancedigital.in/samsung-s20-plu...
# 212  https://www.reliancedigital.in/samsung-s20-plu...
# 213  https://www.reliancedigital.in/samsung-galaxy-...
# 214  https://www.reliancedigital.in/samsung-a70s-12...
# 215  https://www.reliancedigital.in/samsung-a70s-12...
#
# [216 rows x 3 columns]

# %% [markdown]
# ### Spliting Mobile

# %%
df["Mobile"].str.split(',',n=1)
# Out:
# 0                 [Samsung Galaxy A22 128 GB 6 GB Black]
# 1      [Samsung A12 128 GB,  4 GB RAM, Black, Mobile ...
# 2      [Samsung A12 64 GB,  4 GB RAM, Blue, Mobile Ph...
# 3      [Samsung A12 64 GB,  4 GB RAM, White, Mobile P...
# 4      [Samsung A12 128 GB,  6 GB RAM, Blue, Mobile P...
#                              ...
# 211    [Samsung S20 Plus 128 GB,  8 GB RAM, Cosmic Bl...
# 212    [Samsung S20 Plus 128 GB,  8 GB RAM, Cloud Blu...
# 213    [Samsung Galaxy A51,  128 GB, 6 GB RAM, Prism ...
# 214    [Samsung A70s 128 GB,  6 GB RAM, Prism Crush W...
# 215    [Samsung A70s 128 GB,  8 GB RAM, Prism Crush B...
# Name: Mobile, Length: 216, dtype: object

# %%
df[['Name','RAM','Color', 'Type']]=df['Mobile'].str.split(',',n=3,expand=True)
df
# Out:
#                                                 Mobile       Price  \
# 0                 Samsung Galaxy A22 128 GB 6 GB Black  ₹18,499.00
# 1    Samsung A12 128 GB, 4 GB RAM, Black, Mobile Phone  ₹13,999.00
# 2      Samsung A12 64 GB, 4 GB RAM, Blue, Mobile Phone  ₹12,999.00
# 3     Samsung A12 64 GB, 4 GB RAM, White, Mobile Phone  ₹12,999.00
# 4     Samsung A12 128 GB, 6 GB RAM, Blue, Mobile Phone  ₹15,499.00
# ..                                                 ...         ...
# 211  Samsung S20 Plus 128 GB, 8 GB RAM, Cosmic Blac...  ₹69,999.00
# 212  Samsung S20 Plus 128 GB, 8 GB RAM, Cloud Blue,...  ₹69,999.00
# 213  Samsung Galaxy A51, 128 GB, 6 GB RAM, Prism Bl...  ₹20,999.00
# 214  Samsung A70s 128 GB, 6 GB RAM, Prism Crush Whi...  ₹28,400.00
# 215  Samsung A70s 128 GB, 8 GB RAM, Prism Crush Bla...  ₹30,500.00
#
#                                               Homepage  \
# 0    https://www.reliancedigital.in/samsung-galaxy-...
# 1    https://www.reliancedigital.in/samsung-a12-128...
# 2    https://www.reliancedigital.in/samsung-a12-64-...
# 3    https://www.reliancedigital.in/samsung-a12-64-...
# 4    https://www.reliancedigital.in/samsung-a12-128...
# ..                                                 ...
# 211  https://www.reliancedigital.in/samsung-s20-plu...
# 212  https://www.reliancedigital.in/samsung-s20-plu...
# 213  https://www.reliancedigital.in/samsung-galaxy-...
# 214  https://www.reliancedigital.in/samsung-a70s-12...
# 215  https://www.reliancedigital.in/samsung-a70s-12...
#
#                                      Name        RAM               Color  \
# 0    Samsung Galaxy A22 128 GB 6 GB Black       None                None
# 1                      Samsung A12 128 GB   4 GB RAM               Black
# 2                       Samsung A12 64 GB   4 GB RAM                Blue
# 3                       Samsung A12 64 GB   4 GB RAM               White
# 4                      Samsung A12 128 GB   6 GB RAM                Blue
# ..                                    ...        ...                 ...
# 211               Samsung S20 Plus 128 GB   8 GB RAM        Cosmic Black
# 212               Samsung S20 Plus 128 GB   8 GB RAM          Cloud Blue
# 213                    Samsung Galaxy A51     128 GB            6 GB RAM
# 214                   Samsung A70s 128 GB   6 GB RAM   Prism Crush White
# 215                   Samsung A70s 128 GB   8 GB RAM   Prism Crush Black
#
#                           Type
# 0                         None
# 1                 Mobile Phone
# 2                 Mobile Phone
# 3                 Mobile Phone
# 4                 Mobile Phone
# ..                         ...
# 211               Mobile Phone
# 212               Mobile Phone
# 213   Prism Blue, Mobile Phone
# 214               Mobile Phone
# 215               Mobile Phone
#
# [216 rows x 7 columns]

# %%
df
# Out:
#                                                 Mobile       Price  \
# 0                 Samsung Galaxy A22 128 GB 6 GB Black  ₹18,499.00
# 1    Samsung A12 128 GB, 4 GB RAM, Black, Mobile Phone  ₹13,999.00
# 2      Samsung A12 64 GB, 4 GB RAM, Blue, Mobile Phone  ₹12,999.00
# 3     Samsung A12 64 GB, 4 GB RAM, White, Mobile Phone  ₹12,999.00
# 4     Samsung A12 128 GB, 6 GB RAM, Blue, Mobile Phone  ₹15,499.00
# ..                                                 ...         ...
# 211  Samsung S20 Plus 128 GB, 8 GB RAM, Cosmic Blac...  ₹69,999.00
# 212  Samsung S20 Plus 128 GB, 8 GB RAM, Cloud Blue,...  ₹69,999.00
# 213  Samsung Galaxy A51, 128 GB, 6 GB RAM, Prism Bl...  ₹20,999.00
# 214  Samsung A70s 128 GB, 6 GB RAM, Prism Crush Whi...  ₹28,400.00
# 215  Samsung A70s 128 GB, 8 GB RAM, Prism Crush Bla...  ₹30,500.00
#
#                                               Homepage  \
# 0    https://www.reliancedigital.in/samsung-galaxy-...
# 1    https://www.reliancedigital.in/samsung-a12-128...
# 2    https://www.reliancedigital.in/samsung-a12-64-...
# 3    https://www.reliancedigital.in/samsung-a12-64-...
# 4    https://www.reliancedigital.in/samsung-a12-128...
# ..                                                 ...
# 211  https://www.reliancedigital.in/samsung-s20-plu...
# 212  https://www.reliancedigital.in/samsung-s20-plu...
# 213  https://www.reliancedigital.in/samsung-galaxy-...
# 214  https://www.reliancedigital.in/samsung-a70s-12...
# 215  https://www.reliancedigital.in/samsung-a70s-12...
#
#                                      Name        RAM               Color  \
# 0    Samsung Galaxy A22 128 GB 6 GB Black       None                None
# 1                      Samsung A12 128 GB   4 GB RAM               Black
# 2                       Samsung A12 64 GB   4 GB RAM                Blue
# 3                       Samsung A12 64 GB   4 GB RAM               White
# 4                      Samsung A12 128 GB   6 GB RAM                Blue
# ..                                    ...        ...                 ...
# 211               Samsung S20 Plus 128 GB   8 GB RAM        Cosmic Black
# 212               Samsung S20 Plus 128 GB   8 GB RAM          Cloud Blue
# 213                    Samsung Galaxy A51     128 GB            6 GB RAM
# 214                   Samsung A70s 128 GB   6 GB RAM   Prism Crush White
# 215                   Samsung A70s 128 GB   8 GB RAM   Prism Crush Black
#
#                           Type
# 0                         None
# 1                 Mobile Phone
# 2                 Mobile Phone
# 3                 Mobile Phone
# 4                 Mobile Phone
# ..                         ...
# 211               Mobile Phone
# 212               Mobile Phone
# 213   Prism Blue, Mobile Phone
# 214               Mobile Phone
# 215               Mobile Phone
#
# [216 rows x 7 columns]

# %%
df.to_excel('Reliance Digitl3.xlsx',index=False)
